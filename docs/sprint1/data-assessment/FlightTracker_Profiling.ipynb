# %% [markdown]
# # FlightTracker Profiling\n\nNotebook reproducible para generar el profiling y los artefactos DQ de Sprint 1.

# %% [markdown]
# ## Flujo sugerido\n\n1. Descargar el BTS productivo a un archivo local.\n2. Exportar un snapshot de OpenSky desde la API live.\n3. Ejecutar `generate_profiles.py` para poblar `results/`.

# %%
from pathlib import Path\nimport subprocess\n\nbase = Path.cwd()\nscript = base / 'generate_profiles.py'\nbts_csv = Path('/tmp/bts_flights_corregido.csv')\nopensky_json = Path('/tmp/opensky_live_sample.json')\n\nprint('Script:', script)\nprint('BTS CSV:', bts_csv)\nprint('OpenSky JSON:', opensky_json)\n\ncmd = [\n    'python3',\n    str(script),\n    '--bts-csv',\n    str(bts_csv),\n    '--opensky-json',\n    str(opensky_json),\n]\nprint(' '.join(cmd))\n# subprocess.run(cmd, check=True)\n
